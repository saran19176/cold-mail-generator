# %%
import chromadb
client = chromadb.Client()
collection = client.create_collection(name = "my_collection")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import chromadb
#       2 client = chromadb.Client()
#       3 collection = client.create_collection(name = "my_collection")
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
import chromadb
client = chromadb.Client()
collection = client.create_collection(name = "my_collection")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import chromadb
#       2 client = chromadb.Client()
#       3 collection = client.create_collection(name = "my_collection")
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
# !pip install chromadb
# Out:
# ...
#   Using cached chromadb-1.0.5-cp39-abi3-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached uvicorn-0.34.1-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached posthog-3.25.0-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached opentelemetry_api-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl.metadata (2.5 kB)
# ...

# %%
pip install chromadb
# Out:
# ...
#
# ...

# %%
# %pip install chromadb
# Out:
# ...
#
# ...

# %%
import chromadb
client = chromadb.Client()
collection = client.create_collection(name = "my_collection")

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids= [
        'id1', 'id2'
    ]
)
# Out:
# C:\Users\91994\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [01:26<00:00, 963kiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York',
#   'This document is about Delhi'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
results = collection.query(
    query_texts=["Query about chole bhature"],
    n_results=2
)
results
# Out:
# {'ids': [['id2', 'id1']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.5705877542495728, 1.9602339267730713]]}

# %%
results = collection.query(
    query_texts=["Query about pizza"],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.7035534381866455, 1.7959264516830444]]}

# %%
results = collection.query(
    query_texts=["Query about empire state building"],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.3137967586517334, 1.4210602045059204]]}

# %%
results = collection.query(
    query_texts=["Query about trump"],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.4500365257263184, 1.731195092201233]]}

# %%
results = collection.query(
    query_texts=["Query about modi"],
    n_results=2
)
results
# Out:
# {'ids': [['id2', 'id1']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.3168882131576538, 1.7320530414581299]]}

# %%
collection.add(
    documents=[
        "This document about new york",
        "this document about delhi"
    ],
    ids=[
        'id3', 'id4'
    ],
    metadatas=[
        {"url" : "https://en.wikipedia.org/wiki/New_York_City"},
        {"url" : "https://en.wikipedia.org/wiki/Delhi"}
    ]
)

results = collection.query(
    query_texts=["Query about modi"],
    n_results=2
)
results
# Out:
# {'ids': [['id4', 'id2']],
#  'embeddings': None,
#  'documents': [['this document about delhi', 'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'url': 'https://en.wikipedia.org/wiki/Delhi'}, None]],
#  'distances': [[1.3138271570205688, 1.3168882131576538]]}
